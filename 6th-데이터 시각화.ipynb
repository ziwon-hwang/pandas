# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

mpl.rcParams['axes.unicode_minus'] = False

# %%
df = pd.DataFrame(np.random.rand(6, 3),
                  columns=['a', 'b', 'c'])
df['d'] = pd.Series([1, 1, 1, 0.5, 0.5, 0.3])
df
# Out:
#           a         b         c    d
# 0  0.566467  0.091216  0.725554  1.0
# 1  0.557347  0.194860  0.499323  1.0
# 2  0.134605  0.344402  0.808271  1.0
# 3  0.553982  0.268946  0.401824  0.5
# 4  0.235839  0.568493  0.494158  0.5
# 5  0.003081  0.742635  0.332573  0.3

# %% [markdown]
# # 1. bar plot 막대그래프

# %%
df.plot(kind = 'bar')

# %%
df.plot?

# %%
df.plot.bar()

# %%
df.plot.bar()
plt.legend(loc = 'lower right')

# %%
df.plot.bar()
plt.legend(loc = 'lower right')
plt.xlabel('인덱스 번호')
plt.ylabel('값')
# Out:
# Text(0, 0.5, '값')

# %%
from matplotlib import font_manager, rc

f_name = font_manager.FontProperties(fname='C:/Windows/Fonts/NGULIM.ttf').get_name()
rc('font', family=f_name)

# %%
df.plot.bar()
plt.legend(loc = 'lower right')
plt.xlabel('인덱스 번호')
plt.ylabel('값')
plt.title('세로 막대 그래프')
# Out:
# Text(0.5, 1.0, '세로 막대 그래프')

# %%
df.plot.bar(title = '막대그래프2')
plt.ylim(0, 1.2)
plt.savefig('gragh2.pdf')

# %%
# %matplotlib qt5

df.plot.bar(title = '막대그래프3')

# %%
df.iloc[5].plot(kind = 'bar')

# %%
# %matplotlib inline
df.iloc[5].plot.bar()

# %%
plt.axhline(0.3, color = 'k')

# %%
plt.axvline(0.3, color = 'c')

# %%
df.iloc[5].plot.bar()
plt.axhline(0.3, color = 'k')

# %%
sns.countplot(data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-c6841deafd0a> in <module>
# ----> 1 sns.countplot(data=df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3546         raise TypeError("Cannot pass values for both `x` and `y`")
#    3547     else:
# -> 3548         raise TypeError("Must pass values for either `x` or `y`")
#    3549
#    3550     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#
# TypeError: Must pass values for either `x` or `y`

# %%
sns.countplot?

# %%
sns.countplot(data=df, x='d')

# %%
sns.barplot(data=df)

# %%
df.plot.bar(stacked=True)

# %%
df.plot.barh()

# %%
df.plot.barh(stacked=True)

# %%
sd =pd.read_csv('se_sales.txt', skiprows=7, sep='\t', encoding='utf-8')
sd
# Out:
#       년도  분기     CE     IM     DS     SC    DP
# 0   2014   1  11.32  32.44  15.56   9.39  6.10
# 1   2014   2  13.00  28.45  16.23   9.78  6.33
# 2   2014   3  11.60  24.58  16.29   9.89  6.25
# 3   2014   4  14.27  26.29  17.71  10.66  7.05
# 4   2015   1  10.26  25.89  17.10  10.27  6.85
# 5   2015   2  11.20  26.06  17.87  11.29  6.62
# 6   2015   3  11.59  26.61  20.31  12.82  7.49
# 7   2015   4  13.85  25.00  19.74  13.21  6.53
# 8   2016   1  10.62  27.60  17.18  11.15  6.04
# 9   2016   2  11.55  26.56  18.43  12.00  6.42
# 10  2016   3  11.24  22.54  20.29  13.15  7.06
# 11  2016   4  13.64  23.61  22.26  14.86  7.42

# %%
sd =pd.read_csv('se_sales.txt', skiprows=7, index_col=['년도'], sep='\t', encoding='utf-8')
sd
# Out:
#       분기     CE     IM     DS     SC    DP
# 년도
# 2014   1  11.32  32.44  15.56   9.39  6.10
# 2014   2  13.00  28.45  16.23   9.78  6.33
# 2014   3  11.60  24.58  16.29   9.89  6.25
# 2014   4  14.27  26.29  17.71  10.66  7.05
# 2015   1  10.26  25.89  17.10  10.27  6.85
# 2015   2  11.20  26.06  17.87  11.29  6.62
# 2015   3  11.59  26.61  20.31  12.82  7.49
# 2015   4  13.85  25.00  19.74  13.21  6.53
# 2016   1  10.62  27.60  17.18  11.15  6.04
# 2016   2  11.55  26.56  18.43  12.00  6.42
# 2016   3  11.24  22.54  20.29  13.15  7.06
# 2016   4  13.64  23.61  22.26  14.86  7.42

# %%
sd_g=sd.groupby('년도').sum()
sd_g
# Out:
#       분기     CE      IM     DS     SC     DP
# 년도
# 2014  10  50.19  111.76  65.79  39.72  25.73
# 2015  10  46.90  103.56  75.02  47.59  27.49
# 2016  10  47.05  100.31  78.16  51.16  26.94

# %%
sd_g2 = sd_g.drop(columns='분기')
sd_g2
# Out:
#          CE      IM     DS     SC     DP
# 년도
# 2014  50.19  111.76  65.79  39.72  25.73
# 2015  46.90  103.56  75.02  47.59  27.49
# 2016  47.05  100.31  78.16  51.16  26.94

# %%
sd_g2.plot.bar(stacked=True, color=['r', 'g', 'b', 'y', 'brown'])
plt.legend(('CE부문', 'IM부문', 'DS부문', 'SC부문','DP부문'),  loc = 'upper right')
plt.title('삼성전자 년도별 매출액 추이')
plt.ylabel('매출액(조원)')
# Out:
# Text(0, 0.5, '매출액(조원)')

# %%
sd.index
# Out:
# Int64Index([2014, 2014, 2014, 2014, 2015, 2015, 2015, 2015, 2016, 2016, 2016,
#             2016],
#            dtype='int64', name='년도')

# %%
aaa = pd.read_csv("se_sales.txt",  skiprows=7, index_col=['년도'], sep='\t', encoding='utf-8', parse_dates = ["년도"])
aaa
# Out:
#             분기     CE     IM     DS     SC    DP
# 년도
# 2014-01-01   1  11.32  32.44  15.56   9.39  6.10
# 2014-01-01   2  13.00  28.45  16.23   9.78  6.33
# 2014-01-01   3  11.60  24.58  16.29   9.89  6.25
# 2014-01-01   4  14.27  26.29  17.71  10.66  7.05
# 2015-01-01   1  10.26  25.89  17.10  10.27  6.85
# 2015-01-01   2  11.20  26.06  17.87  11.29  6.62
# 2015-01-01   3  11.59  26.61  20.31  12.82  7.49
# 2015-01-01   4  13.85  25.00  19.74  13.21  6.53
# 2016-01-01   1  10.62  27.60  17.18  11.15  6.04
# 2016-01-01   2  11.55  26.56  18.43  12.00  6.42
# 2016-01-01   3  11.24  22.54  20.29  13.15  7.06
# 2016-01-01   4  13.64  23.61  22.26  14.86  7.42

# %%
aaa.index
# Out:
# DatetimeIndex(['2014-01-01', '2014-01-01', '2014-01-01', '2014-01-01',
#                '2015-01-01', '2015-01-01', '2015-01-01', '2015-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01'],
#               dtype='datetime64[ns]', name='년도', freq=None)

# %% [markdown]
# # 2. (꺽은)선 그래프

# %%
df
# Out:
#           a         b         c    d
# 0  0.566467  0.091216  0.725554  1.0
# 1  0.557347  0.194860  0.499323  1.0
# 2  0.134605  0.344402  0.808271  1.0
# 3  0.553982  0.268946  0.401824  0.5
# 4  0.235839  0.568493  0.494158  0.5
# 5  0.003081  0.742635  0.332573  0.3

# %%
df.plot()

# %%
df.plot.line()

# %%
plt.plot(df)
# Out:
# [<matplotlib.lines.Line2D at 0x1be066b6e10>,
#  <matplotlib.lines.Line2D at 0x1be066d7390>,
#  <matplotlib.lines.Line2D at 0x1be066d74e0>,
#  <matplotlib.lines.Line2D at 0x1be066d7630>]

# %%
sns.lineplot(data=df)

# %%
df.plot(marker = 's')

# %%
df.plot(marker = 's', linestyle = 'dashed', linewidth = 3, markersize = 12)

# %%
plt.plot(df, marker = 's', linestyle = 'dashed', linewidth = 3, markersize = 12)
# Out:
# [<matplotlib.lines.Line2D at 0x1be0685ddd8>,
#  <matplotlib.lines.Line2D at 0x1be06895550>,
#  <matplotlib.lines.Line2D at 0x1be068956a0>,
#  <matplotlib.lines.Line2D at 0x1be068957f0>]

# %%
plt.plot(df, 's--', linewidth = 3, markersize = 12)
# Out:
# [<matplotlib.lines.Line2D at 0x1be068f1b70>,
#  <matplotlib.lines.Line2D at 0x1be068f1c88>,
#  <matplotlib.lines.Line2D at 0x1be068f1dd8>,
#  <matplotlib.lines.Line2D at 0x1be068f1f28>]

# %%
df.plot('s--', linewidth = 3, markersize = 12)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 's--'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-0b008b4ceab0> in <module>
# ----> 1 df.plot('s--', linewidth = 3, markersize = 12)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2940                           fontsize=fontsize, colormap=colormap, table=table,
#    2941                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2942                           sort_columns=sort_columns, **kwds)
#    2943     __call__.__doc__ = plot_frame.__doc__
#    2944
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1971                  yerr=yerr, xerr=xerr,
#    1972                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1973                  **kwds)
#    1974
#    1975
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1761                 if is_integer(x) and not data.columns.holds_integer():
#    1762                     x = data_cols[x]
# -> 1763                 elif not isinstance(data[x], ABCSeries):
#    1764                     raise ValueError("x must be a label or position")
#    1765                 data = data.set_index(x)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 's--'

# %%
sns.lineplot(data=df, marker='s', linewidth=3, markersize=12)

# %%
plt.plot(df['a'], 'bo--')
plt.plot(df['b'], 'yd-')
plt.plot(df['c'], 'gs-.')
plt.plot(df['d'], 'r^-.')
plt.legend( ('a', 'b', 'c', 'd'), loc='best' )

# %%
df
# Out:
#           a         b         c    d
# 0  0.566467  0.091216  0.725554  1.0
# 1  0.557347  0.194860  0.499323  1.0
# 2  0.134605  0.344402  0.808271  1.0
# 3  0.553982  0.268946  0.401824  0.5
# 4  0.235839  0.568493  0.494158  0.5
# 5  0.003081  0.742635  0.332573  0.3

# %%
df.describe()
# Out:
#               a         b         c         d
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.341887  0.368425  0.543617  0.716667
# std    0.249337  0.243927  0.185578  0.318852
# min    0.003081  0.091216  0.332573  0.300000
# 25%    0.159914  0.213381  0.424908  0.500000
# 50%    0.394911  0.306674  0.496741  0.750000
# 75%    0.556505  0.512470  0.668996  1.000000
# max    0.566467  0.742635  0.808271  1.000000

# %%
sns.pointplot(data=df)

# %%
sns.pointplot(data=df, x='d', y='a')
sns.pointplot(data=df, x='d', y='b', color='r')
sns.pointplot(data=df, x='d', y='c', color='g')

# %%
df
# Out:
#           a         b         c    d
# 0  0.566467  0.091216  0.725554  1.0
# 1  0.557347  0.194860  0.499323  1.0
# 2  0.134605  0.344402  0.808271  1.0
# 3  0.553982  0.268946  0.401824  0.5
# 4  0.235839  0.568493  0.494158  0.5
# 5  0.003081  0.742635  0.332573  0.3

# %%
df2 = df.cumsum()
df2
# Out:
#           a         b         c    d
# 0  0.566467  0.091216  0.725554  1.0
# 1  1.123813  0.286076  1.224877  2.0
# 2  1.258419  0.630478  2.033149  3.0
# 3  1.812401  0.899424  2.434973  3.5
# 4  2.048240  1.467917  2.929131  4.0
# 5  2.051320  2.210551  3.261704  4.3

# %%
df2.plot()

# %%
df
# Out:
#           a         b         c    d
# 0  0.566467  0.091216  0.725554  1.0
# 1  0.557347  0.194860  0.499323  1.0
# 2  0.134605  0.344402  0.808271  1.0
# 3  0.553982  0.268946  0.401824  0.5
# 4  0.235839  0.568493  0.494158  0.5
# 5  0.003081  0.742635  0.332573  0.3

# %%
df.plot.area()

# %%
df.plot.area(stacked=False)

# %%
df.plot()

# %% [markdown]
# # 3. 히스토그램

# %%
np.random.seed(1234)
df2= pd.DataFrame({'a': np.random.randn(1000) + 1, 
                    'b': np.random.randn(1000),
                    'c': np.random.randn(1000) - 1}, 
                   columns=['a', 'b', 'c'])
df2
# Out:
#             a         b         c
# 0    1.471435 -1.582208 -2.187041
# 1   -0.190976 -1.620190  0.617082
# 2    2.432707  0.046562 -1.042681
# 3    0.687348 -1.679829 -0.632016
# 4    0.279411  1.395892  0.809185
# 5    1.887163 -0.844971  0.020068
# 6    1.859588  0.814007  0.589721
# 7    0.363476 -0.049742  0.238117
# 8    1.015696  0.534247 -1.976524
# 9   -1.242685 -0.807009 -1.887750
# 10   2.150036  0.841641 -1.577326
# 11   1.991946 -0.558173 -0.197045
# 12   1.953324 -0.629157 -0.239512
# 13  -1.021255  1.177667 -2.585657
# 14   0.665923 -0.845081 -2.691415
# 15   1.002118 -0.281439  0.054737
# 16   1.405453  1.719957 -1.501993
# 17   1.289092 -1.077500 -1.294687
# 18   2.321158 -1.378282 -1.501388
# 19  -0.546906 -0.295144 -1.632003
# 20   0.797354  1.628856 -0.894063
# 21   0.344031 -0.377438 -0.419113
# 22   1.193421  0.026758 -1.027569
# 23   1.553439 -0.922238 -3.467703
# 24   2.318152 -1.416757 -2.126165
# 25   0.530695  0.863528 -1.269188
# 26   1.675554 -0.204406 -1.582967
# 27  -0.817027 -2.109840 -0.687384
# 28   0.816891 -0.526084 -0.605310
# 29   2.058969  0.052376 -0.684274
# ..        ...       ...       ...
# 970  1.889663  0.593436  0.481404
# 971  2.134157  0.647215 -1.401636
# 972  2.731630 -1.081979  0.634118
# 973  0.294480 -0.045519 -2.764545
# 974 -0.285810  0.311316  1.134186
# 975  0.361790 -0.854228 -1.521587
# 976  1.700785 -2.569458 -1.748533
# 977  1.881141  0.144742 -0.894345
# 978  0.346796 -0.296135 -1.701489
# 979 -0.319966 -0.329168 -0.391921
# 980  0.181287  1.108549 -1.486693
# 981  1.162702  0.322386 -0.662301
# 982  1.669760 -1.955977 -0.050922
# 983  0.425920  0.371284 -1.491731
# 984  1.743687 -0.703777 -1.551622
# 985  1.616713  0.556622 -0.953800
# 986  1.971867  1.957004 -0.995841
# 987  0.288096  0.841030 -1.858702
# 988  0.264307  0.562552 -0.255113
# 989  0.036536  0.442317 -1.392201
# 990  1.459138 -0.265072 -1.731710
# 991  1.656238  1.222252 -1.045766
# 992  1.751503  0.166502 -2.077163
# 993 -0.872184 -1.243429 -1.882983
# 994  0.443720  0.348579 -0.367070
# 995  1.272164  0.632579 -0.296966
# 996  1.931546  2.013382 -2.093268
# 997  1.327532  0.781463 -0.813530
# 998  1.740814  2.147152  1.679854
# 999  0.198095 -0.908351  0.075631
#
# [1000 rows x 3 columns]

# %%
df2.plot.hist()

# %%
df2.plot.hist(alpha=0.5)

# %%
df2['a'].plot.hist()

# %%
df2['a'].plot.hist(bins = 20)

# %%
df2['a'].plot.hist(orientation='horizontal')

# %%
df2['a'].plot.hist(cumulative=True ,orientation='horizontal')

# %%
df2.plot.hist?

# %% [markdown]
# ## subplot 그리기

# %% [markdown]
# #### 그래프의 크기 조절
#
# plt.fiture ( figsize = (너비, 높이), facecolor = '배경색깔')

# %% [markdown]
# #### subplot의 위치 지정
#
# ##### 2단일때
# * 상 : subplot(2, 1, 1)
# * 하 : subplot(2, 1, 2)
#
#
# * 좌 : subplot(1, 2, 1)
# * 우 : subplot(1, 2, 2)
#
#
# ##### 4단일때
# * 좌상 : subplot(2, 2, 1)
# * 우상 : subplot(2, 2, 2)
# * 좌하 : subplot(2, 2, 3)
# * 우하 : subplot(2, 2, 4)

# %% [markdown]
# #### subplot 간의 간격 설정
#
# plt.subplots_adjust(wspace=0.3, hspace=0.4)
#
# wspace : subplot 끼리의 폭 간격의 비율(기본 0.2)
#
# hspace : subplot 끼리의높이 간격의 비율(기본 0.2)

# %%
plt.subplot(2, 2, 1)
df2['a'].plot.hist(alpha=0.5)

plt.subplot(2, 2, 2)
df2['a'].plot.hist()

plt.subplot(2, 2, 3)
df2['a'].plot.hist(orientation='horizontal')

plt.subplot(2, 2, 4)
df2['a'].plot.hist(cumulative=True ,orientation='horizontal')

# %%
plt.figure(figsize=((8, 4)))
plt.subplots_adjust(wspace=0.3, hspace=0.4)


plt.subplot(2, 2, 1)
df2['a'].plot.hist(alpha=0.5)

plt.subplot(2, 2, 2)
df2['a'].plot.hist()

plt.subplot(2, 2, 3)
df2['a'].plot.hist(orientation='horizontal')

plt.subplot(2, 2, 4)
df2['a'].plot.hist(cumulative=True ,orientation='horizontal')

# %%
df2[ ['a', 'b', 'c'] ].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001BE0A76FE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BE0A8E2438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BE0A908908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BE0A932E80>]],
#       dtype=object)

# %%
df2.hist(figsize = (16, 14))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001BE0AB6AF98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BE0AB8C5C0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001BE0ABB3A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001BE0ABDDFD0>]],
#       dtype=object)

# %%
df2.plot.hist()

# %% [markdown]
# ## cf) kde 커널밀도함수 (Kernel Density Estimate plot)
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#density-plot

# %% [markdown]
# * 히스토그램은 이산형으로 그래프가 나옴(끊기는 형태), Density plot은 부드러운 곡선형태로 그래프 그려 줌
# * 곡선으로 만들때 kde방법으로 추정 함
# * 커널 밀도 추정(KDE)은 임의 변수의 확률 밀도 함수(PDF)를 추정하는 비모수적 방법
# * 가우스 커널을 사용, 자동 대역폭 결정 포함
# * 커널 밀도 추정치는 적절한 커널을 사용, 매끄럽고 연속성과 같은 속성을 부여할 수 있음
# * 커널 함수는 원점을 중심으로 대칭, 적분값이 1인 함수
#
# ### 정규분포
# * 정규분포(normal distribution) 또는 가우시안 분포(Gaussian distribution)는 연속 확률 분포
# * 정규분포는 중심극한정리에 의해 독립적인 확률변수들의 평균은 정규분포에 가까워지는 성질이 있음

# %%
df2.plot.hist()

# %%
df2.plot.density()

# %%
df2.plot.kde()

# %%
df2['a'].plot.density()

# %%
sns.distplot(df2['a'])

# %%
sns.distplot(df2['a'], kde=False)

# %%
sns.distplot(df2['a'], hist=False)

# %% [markdown]
# # 4. box plot 상자 수염 그래프
#
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#box-plots
# * box-and-whisker plot/ box-and-whisker diagram
# * 데이터 날 것 그대로 안 그림, 데이터로부터 통계량 5가지 얻어낸 수치를 그림
# * 통계량 5가지 = 기술통계 정보
# * 최솟값/ 1사분위수/ 2사분위수(중앙값)/ 3사분위수/ 최댓값

# %%
np.random.seed(1004)
df = pd.DataFrame(np.random.rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])
df
# Out:
#           A         B         C         D         E
# 0  0.038952  0.856496  0.746500  0.863928  0.559984
# 1  0.080483  0.231636  0.242264  0.615500  0.607109
# 2  0.104182  0.425848  0.654923  0.871389  0.438489
# 3  0.713791  0.058862  0.909286  0.521817  0.727429
# 4  0.496344  0.127552  0.315885  0.662403  0.305621
# 5  0.221893  0.228571  0.842827  0.675393  0.343624
# 6  0.795700  0.979995  0.568184  0.205780  0.246666
# 7  0.395632  0.774485  0.826586  0.564471  0.590047
# 8  0.419510  0.604399  0.833122  0.673654  0.307633
# 9  0.058230  0.335766  0.242338  0.739624  0.319677

# %%
df.describe()
# Out:
#                A          B          C          D          E
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.332472   0.462361   0.618192   0.639396   0.444628
# std     0.276407   0.323358   0.262279   0.190120   0.164642
# min     0.038952   0.058862   0.242264   0.205780   0.246666
# 25%     0.086408   0.229337   0.378960   0.577228   0.310644
# 50%     0.308762   0.380807   0.700712   0.668028   0.391056
# 75%     0.477136   0.731963   0.831488   0.723566   0.582531
# max     0.795700   0.979995   0.909286   0.871389   0.727429

# %%
df.plot.box()

# %%
df['D'].plot.box(sym='r+')

# %% [markdown]
# * 이상치(특이값)은 빨강에 + 형태로 표시하라: sym='r+'

# %%
color = {'boxes': 'DarkGreen', 'whiskers': 'DarkOrange',
         'medians': 'DarkBlue', 'caps': 'Gray'}
df.plot.box(color=color, sym='r+')

# %%
df.boxplot(grid = True)

# %%
df.plot.box(vert=False)

# %% [markdown]
# * box plot에서 축 바꾸는 옵션: vert=False

# %%
df.plot.box(vert=False, positions=[1, 4, 5, 6, 8])

# %%
df2 = df[['A', 'B']]
df2['X'] = pd.Series(['G','H','H','G','G','G','H','H','G','H'])
df2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#           A         B  X
# 0  0.038952  0.856496  G
# 1  0.080483  0.231636  H
# 2  0.104182  0.425848  H
# 3  0.713791  0.058862  G
# 4  0.496344  0.127552  G
# 5  0.221893  0.228571  G
# 6  0.795700  0.979995  H
# 7  0.395632  0.774485  H
# 8  0.419510  0.604399  G
# 9  0.058230  0.335766  H

# %%
df2.boxplot()

# %%
df2.boxplot(by = 'X')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001BE0CBA3B70>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001BE0CC10908>],
#       dtype=object)

# %% [markdown]
# # 5.파이 그래프
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#pie-plot
# * https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.pie.html#pandas.DataFrame.plot.pie
# * https://seaborn.pydata.org/
# * seaborn에서는 파이 차트 지원 안함 https://github.com/mwaskom/seaborn/issues/766

# %%
np.random.seed(1004)
ss = pd.Series(3 * np.random.rand(4),
                   index=['a', 'b', 'c', 'd'])
ss
# Out:
# a    0.116855
# b    2.569488
# c    2.239501
# d    2.591784
# dtype: float64

# %%
ss.plot.pie(figsize = (6, 6))

# %%
ss.plot.pie(labels=['AA', 'BB', 'CC', 'DD'],
            colors=['r', 'g', 'b', 'c'],
            autopct='%.2f', fontsize=15, figsize=(6, 6))

# %%
ss.plot.pie(labels=['AA', 'BB', 'CC', 'DD'],
            colors=['r', 'g', 'b', 'c'],
            autopct='%.2f', fontsize=15, figsize=(6, 6),
            explode = [0.1, 0, 0, 0.1],
            rotatelabels = 25)

# %%
df = pd.DataFrame({'mass': [0.330, 4.87 , 5.97],
                   'radius': [2439.7, 6051.8, 6378.1]},
                  index=['Mercury', 'Venus', 'Earth'])
df
# Out:
#          mass  radius
# Mercury  0.33  2439.7
# Venus    4.87  6051.8
# Earth    5.97  6378.1

# %%
df.plot.pie(y='mass', figsize=(5, 5), fontsize = 15)

# %%
df.plot.pie(subplots=True, figsize=(6, 3))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001BE0CE35E10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001BE0CE60EF0>],
#       dtype=object)

# %%
df.plot.pie(subplots=True, figsize=(10, 5))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001BE0CECB048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001BE0CEF00F0>],
#       dtype=object)

# %% [markdown]
# # 6. Scatter plot 산포도

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.plot.scatter( )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-118-6a74a35f9ba1> in <module>
# ----> 1 df.plot.scatter( )
#
# TypeError: scatter() missing 2 required positional arguments: 'x' and 'y'

# %% [markdown]
# * scatter(x=, y=) x='a', y='b'꼭 지정해야 함

# %%
df.plot.scatter(x='total_bill', y='tip')

# %%
sns.lmplot(x="total_bill", y="tip", data=df)

# %% [markdown]
# * https://seaborn.pydata.org/generated/seaborn.lmplot.html

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=df)

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker",
           data=df, fit_reg = False)

# %%
sns.lmplot(x="total_bill", y="tip", hue="sex", data=df)

# %% [markdown]
# # 7. Hexagonal bin plot
# * Hexbin plot은 데이터 많을 때 어느 부분의 수가 큰지 작은지 구분해서 볼 수 없는 산점도(scatter plot)의 단점을 보완
# * scatter plot과 histogram의 보완용
# * 기본색 기준으로, 진할수록 다른 것에 비해 큰 값들이 몰려 있음
# * https://pandas.pydata.org/pandas-docs/stable/user_guide/visualization.html#hexagonal-bin-plot
# * https://seaborn.pydata.org/examples/hexbin_marginals.html

# %%
np.random.seed(1004)
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df['b'] = df['b'] + np.arange(1000)

# %% [markdown]
# * b에 0~999까지 값 더해 줌 np.arange(1000)

# %%
df.tail( )
# Out:
#             a           b
# 995 -0.239106  993.833254
# 996  0.339041  995.565155
# 997  0.767092  995.924927
# 998 -0.707685  996.715501
# 999 -0.515246  998.627703

# %%
df.plot.hexbin(x='a', y='b', gridsize=10)

# %% [markdown]
# 데이터의 크고 작음을 비교할 수 있게 함
#
# 진한초록 = 다른것에 비해 큰 값들이 몰려 있음

# %%
df.plot.hexbin(x='a', y='b', gridsize=35)
