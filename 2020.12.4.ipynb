# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
mpl.rcParams['axes.unicode_minus']=False
from matplotlib import font_manager,rc
f_name=font_manager.FontProperties(fname='C:/Windows/Fonts/GULIM.TTC').get_name()
rc('font',family=f_name)

# %%
 #주피터노특북에 그래프 나타나기 하기 위한것 %matplotlib qt5는 별도의 창

# %%
df=pd.DataFrame(np.random.rand(6,3),columns=['a','b','c'])
df['d']=pd.Series([1,1,1,0.5,0.5,0.3])
index(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-43f2bbb060b8> in <module>
#       1 df=pd.DataFrame(np.random.rand(6,3),columns=['a','b','c'])
#       2 df['d']=pd.Series([1,1,1,0.5,0.5,0.3])
# ----> 3 index(df)
#
# NameError: name 'index' is not defined

# %%
df.plot(kind='bar')

# %%
df.plot(kind='bar') #df.plot.bar()
plt.legend(('토끼','사라소니','당근','먹이'),loc='upper right')
#best,
#upper right, upper left,upper center
#,lower left,lower right,
#right center right center left
#upper center center

# %%
df.plot(kind='bar')
plt.xlabel('인덱스번호')
plt.ylabel('값')
# Out:
# Text(0, 0.5, '값')

# %%
df.plot(kind='bar')
plt.title('세로막대그래프')
# Out:
# Text(0.5, 1.0, '세로막대그래프')

# %%
df.plot(kind='bar')#df.plot.bar()
plt.xlim(0,7)
plt.ylim(0,1.2)
# Out:
# (0, 1.2)

# %%
df.plot(kind='bar')#df.plot.bar()
plt.xlim(0,7)
plt.ylim(0,1.2)
#plt.savefig('saplefig.pdf')#그래프 별도저장
#그래프를 별도의 창에서 그리려면 %matplotline qt5
#쥬피터안에서 그릴려면 %matplotline inline
# Out:
# (0, 1.2)

# %%
df.iloc[5].plot.bar()
plt.axhline(0.3,color='k')

# %%
sns.countplot(data=df,x='d')
#y축:개수
#열기준으로 데이터의 출현횟수

# %%
sns.barplot(data=df) #열대로 평균

# %%
sns.barplot(data=df,x='d',y='a')
#y축:d열에 따른 a열 데이터의 평균
#y축이 연속데이터일때 barplot이 countplot보다 더 낫다
#countplot과 다르게 편차도 표시된다. 특이값 등의 판단에 도움이 된다.

# %%
df.plot.bar(stacked=True)

# %%
df.plot.barh()

# %%
df.plot.barh(stacked=True)

# %%
sd=pd.read_csv('se_sales.txt',skiprows=7,sep='\t',encoding='utf-8')
sd
# Out:
#       년도  분기     CE     IM     DS     SC    DP
# 0   2014   1  11.32  32.44  15.56   9.39  6.10
# 1   2014   2  13.00  28.45  16.23   9.78  6.33
# 2   2014   3  11.60  24.58  16.29   9.89  6.25
# 3   2014   4  14.27  26.29  17.71  10.66  7.05
# 4   2015   1  10.26  25.89  17.10  10.27  6.85
# 5   2015   2  11.20  26.06  17.87  11.29  6.62
# 6   2015   3  11.59  26.61  20.31  12.82  7.49
# 7   2015   4  13.85  25.00  19.74  13.21  6.53
# 8   2016   1  10.62  27.60  17.18  11.15  6.04
# 9   2016   2  11.55  26.56  18.43  12.00  6.42
# 10  2016   3  11.24  22.54  20.29  13.15  7.06
# 11  2016   4  13.64  23.61  22.26  14.86  7.42

# %%
sd=pd.read_csv('se_sales.txt',skiprows=7,index_col=['년도'],sep='\t',encoding='utf-8')
sd
# Out:
#       분기     CE     IM     DS     SC    DP
# 년도
# 2014   1  11.32  32.44  15.56   9.39  6.10
# 2014   2  13.00  28.45  16.23   9.78  6.33
# 2014   3  11.60  24.58  16.29   9.89  6.25
# 2014   4  14.27  26.29  17.71  10.66  7.05
# 2015   1  10.26  25.89  17.10  10.27  6.85
# 2015   2  11.20  26.06  17.87  11.29  6.62
# 2015   3  11.59  26.61  20.31  12.82  7.49
# 2015   4  13.85  25.00  19.74  13.21  6.53
# 2016   1  10.62  27.60  17.18  11.15  6.04
# 2016   2  11.55  26.56  18.43  12.00  6.42
# 2016   3  11.24  22.54  20.29  13.15  7.06
# 2016   4  13.64  23.61  22.26  14.86  7.42

# %%
pd.pivot_table(sd,index=['년도','분기'],aggfunc='mean').head()
# Out:
#             CE    DP     DS     IM     SC
# 년도   분기
# 2014 1   11.32  6.10  15.56  32.44   9.39
#      2   13.00  6.33  16.23  28.45   9.78
#      3   11.60  6.25  16.29  24.58   9.89
#      4   14.27  7.05  17.71  26.29  10.66
# 2015 1   10.26  6.85  17.10  25.89  10.27

# %%
sd_g=sd.groupby('년도').sum()
sd_g
# Out:
#       분기     CE      IM     DS     SC     DP
# 년도
# 2014  10  50.19  111.76  65.79  39.72  25.73
# 2015  10  46.90  103.56  75.02  47.59  27.49
# 2016  10  47.05  100.31  78.16  51.16  26.94

# %%
sd_g2=sd_g.drop(columns='분기')
sd_g2
# Out:
#          CE      IM     DS     SC     DP
# 년도
# 2014  50.19  111.76  65.79  39.72  25.73
# 2015  46.90  103.56  75.02  47.59  27.49
# 2016  47.05  100.31  78.16  51.16  26.94

# %%
sd_g2.plot.bar(stacked=True,color=['r','g','b','y','brown'])
plt.legend(('CE부문','IM부문','3','4,','5'),loc='upper right')
plt.ylabel('매출액(조원)')
# Out:
# Text(0, 0.5, '매출액(조원)')

# %%
sd_g2.index
# Out:
# Int64Index([2014, 2015, 2016], dtype='int64', name='년도')

# %%
sd.index
# Out:
# Int64Index([2014, 2014, 2014, 2014, 2015, 2015, 2015, 2015, 2016, 2016, 2016,
#             2016],
#            dtype='int64', name='년도')

# %%
aaa=pd.read_csv('se_sales.txt',skiprows=7,index_col=['년도'],sep='\t',encoding='utf-8',parse_dates=['년도']
        )
aaa
# Out:
#             분기     CE     IM     DS     SC    DP
# 년도
# 2014-01-01   1  11.32  32.44  15.56   9.39  6.10
# 2014-01-01   2  13.00  28.45  16.23   9.78  6.33
# 2014-01-01   3  11.60  24.58  16.29   9.89  6.25
# 2014-01-01   4  14.27  26.29  17.71  10.66  7.05
# 2015-01-01   1  10.26  25.89  17.10  10.27  6.85
# 2015-01-01   2  11.20  26.06  17.87  11.29  6.62
# 2015-01-01   3  11.59  26.61  20.31  12.82  7.49
# 2015-01-01   4  13.85  25.00  19.74  13.21  6.53
# 2016-01-01   1  10.62  27.60  17.18  11.15  6.04
# 2016-01-01   2  11.55  26.56  18.43  12.00  6.42
# 2016-01-01   3  11.24  22.54  20.29  13.15  7.06
# 2016-01-01   4  13.64  23.61  22.26  14.86  7.42

# %%
df
# Out:
#           a         b         c    d
# 0  0.135662  0.193350  0.776364  1.0
# 1  0.085847  0.738293  0.049130  1.0
# 2  0.893749  0.535803  0.213082  1.0
# 3  0.843716  0.089330  0.557214  0.5
# 4  0.012029  0.707014  0.048593  0.5
# 5  0.954641  0.319350  0.632260  0.3

# %% [markdown]
# *꺽은 선 그래프

# %%
df.plot()  #kind='line'

# %%
df.plot.line()

# %%
df.plot()

# %%
plt.plot(df)  #얘는 범례없음

# %%
plt.plot(df)
#plt.legend(('토끼','사라소니','당근','먹이'),loc='upper right')

# %%
sns.lineplot(data=df)

# %%
df.plot(marker='s') #s는 스퀘어 ,마커찍기

# %%
df.plot(marker='s',linestyle='dashed',linewidth=3,markersize=12)

# %%
plt.plot(df,marker='s',linestyle='dashed',linewidth=3,markersize=12)
#plt.legend(('토끼','사라소니','당근','먹이'),loc='upper right')

# %%
plt.plot(df,'s--',linewidth=3,markersize=12) #marker='s--'아니라 라인스타일과 합쳐서 's--'로 바로 쓴다

# %%
df.plot(marker='s--',linewidth=3,markersize=12) #df는 matplot을 이용해서 그린것과다르게 에러남
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     308             try:
# --> 309                 Path(marker)
#     310                 self._marker_function = self._set_vertices
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\path.py in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     126         """
# --> 127         vertices = _to_unmasked_float_array(vertices)
#     128         if vertices.ndim != 2 or vertices.shape[1] != 2:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _to_unmasked_float_array(x)
#    1389     else:
# -> 1390         return np.asarray(x, float)
#    1391
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      84     """
# ...

# %% [markdown]
# -,--,:,-. 실선,파선,점선,파점선
#
# r,g,b,n,c,y,k,w
#
# o,s,x,^,d ,원,사각형,x,삼각형,다이아몬드

# %%
sns.lineplot(data=df,marker='s',linewidth=3,markersize=12)

# %%
plt.plot(df['a'],'bo--')

# %%
plt.plot(df['a'],'bo--') #plt를 사용시 따로 지정해줘야함
plt.plot(df['b'],'yd--')
plt.plot(df['c'],'gs--')
plt.plot(df['d'],'r^-.')
plt.legend(('a','b','c','d'),loc='best')

# %%
sns.pointplot(data=df) #선길이는 편차를 의미

# %%
df.describe() #괄호 꼭 붙혀줘야함,size할때도
# Out:
#               a         b         c         d
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.487607  0.430523  0.379440  0.716667
# std    0.451959  0.271027  0.316009  0.318852
# min    0.012029  0.089330  0.048593  0.300000
# 25%    0.098301  0.224850  0.090118  0.500000
# 50%    0.489689  0.427576  0.385148  0.750000
# 75%    0.881240  0.664211  0.613498  1.000000
# max    0.954641  0.738293  0.776364  1.000000

# %%
sns.pointplot(data=df,x='d',y='a')
sns.pointplot(data=df,x='d',y='b',color='r')
sns.pointplot(data=df,x='d',y='c',color='b')

# %%
df2=df.cumsum() #열기준으로 쌓아올림
#stacked는 행기준으로 abcd순으로 쌓아올림
df2
# Out:
#           a         b         c    d
# 0  0.135662  0.193350  0.776364  1.0
# 1  0.221509  0.931643  0.825494  2.0
# 2  1.115258  1.467445  1.038576  3.0
# 3  1.958974  1.556775  1.595790  3.5
# 4  1.971002  2.263789  1.644383  4.0
# 5  2.925643  2.583139  2.276642  4.3

# %%
df
# Out:
#           a         b         c    d
# 0  0.135662  0.193350  0.776364  1.0
# 1  0.085847  0.738293  0.049130  1.0
# 2  0.893749  0.535803  0.213082  1.0
# 3  0.843716  0.089330  0.557214  0.5
# 4  0.012029  0.707014  0.048593  0.5
# 5  0.954641  0.319350  0.632260  0.3

# %%
df.plot.area() #Nan 값이 있으면 자동으로0으로 채워서 그려줌
#stacked=True로 고정값

# %%
df.plot.area(stacked=False) #꺽은선그래프에 면적채운걸로 보여줌

# %%
df.plot()

# %%
np.random.seed(1234)
df2=pd.DataFrame({'a':np.random.randn(1000)+1,'b':np.random.randn(1000),
        
                'c':np.random.randn(1000)-1},columns=['a','b','c'])
df2
# Out:
#             a         b         c
# 0    1.471435 -1.582208 -2.187041
# 1   -0.190976 -1.620190  0.617082
# 2    2.432707  0.046562 -1.042681
# 3    0.687348 -1.679829 -0.632016
# 4    0.279411  1.395892  0.809185
# ..        ...       ...       ...
# 995  1.272164  0.632579 -0.296966
# 996  1.931546  2.013382 -2.093268
# 997  1.327532  0.781463 -0.813530
# 998  1.740814  2.147152  1.679854
# 999  0.198095 -0.908351  0.075631
#
# [1000 rows x 3 columns]

# %%
df2.plot.hist()

# %%
df2.plot.hist(alpha=0.5) #투명도

# %% [markdown]
# 외도 첨도 파악하기

# %%
df2['a'].plot.hist() #히스토그램은 데이터의 빈도수를 보여줌

# %%
df2['a'].plot.hist(bins=20)

# %%
df2['a'].plot.hist(orientation='horizontal')

# %%
df2['a'].plot.hist(cumulative=True,orientation='horizontal')

# %% [markdown]
# 상 plt.subplot(2,1,1)
#
# 하plt.subplot(2,1,2)
#
# 좌plt.subplot(1,2,1)
#
# 우plt.subplot(1,2,2)
#
# 좌상plt.subplot(2,2,1)
#
# 우상plt.subplot(2,2,2)
#
# 좌하plt.subplot(2,2,3)
#
# 우하plt.subplot(2,2,4)

# %%
#subplot을 이요하면 한화면 여러개의 그래프를 볼수 있다
plt.subplot(2,2,1)
df2['a'].plot.hist(alpha=0.5)

plt.subplot(2,2,2)
df2['a'].plot.hist()

plt.subplot(2,2,3)
df2['a'].plot.hist(orientation='horizontal')

plt.subplot(2,2,4)
df2['a'].plot.hist(cumulative=True,orientation='horizontal')

# %%
plt.figure(figsize=(8,4))
plt.subplots_adjust(wspace=0.3,hspace=0.4)
#각 그래프별 사이즈 지정
#그래프 간 높이폭 길이 조정
plt.subplot(2,2,1)
df2['a'].plot.hist(alpha=0.5)

plt.subplot(2,2,2)
df2['a'].plot.hist()

plt.subplot(2,2,3)
df2['a'].plot.hist(orientation='horizontal')

plt.subplot(2,2,4)
df2['a'].plot.hist(cumulative=True,orientation='horizontal')

# %%
df2[['a','b','c']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000227EB3EF9C8>,
# ...
#       dtype=object)

# %%
df2.hist(figsize=(16,14))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000227EB5CBD88>,
# ...
#       dtype=object)

# %%
df2.plot.hist()

# %%
df2.plot.density() #밀도추정방식

# %%
df2.plot.kde() #kde:밀도추정방식 중 하나

# %%
df2['a'].plot.density()

# %%
sns.distplot(df2['a'])

# %%
sns.distplot(df2['a'],kde=False)

# %%
sns.distplot(df2['a'],hist=False)

# %%
color={'boxes':'DarkGreen','whiskers':'DarkOrange',
      'medians':'DarkBlue','caps':'Gray'}
df2.plot.box(color=color)

# %%
df2.plot.box(sym='r+') #특이값(이상치)을 처리하는 방식

# %%
#기초통계,기술통계 총5개 통계량을 가지고 그래프 그림
df.describe()
# Out:
#               a         b         c         d
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.487607  0.430523  0.379440  0.716667
# std    0.451959  0.271027  0.316009  0.318852
# min    0.012029  0.089330  0.048593  0.300000
# 25%    0.098301  0.224850  0.090118  0.500000
# 50%    0.489689  0.427576  0.385148  0.750000
# 75%    0.881240  0.664211  0.613498  1.000000
# max    0.954641  0.738293  0.776364  1.000000

# %% [markdown]
# boxes,whiskers,medians,caps
#
# 상자,수염,중앙값,최대최소값

# %%
df.boxplot(grid=True)#df.plot.box()

# %%
df.boxplot(vert=False)#df.plot.box()

# %%
df.boxplot(vert=False,positions=[0.2,0.3,0.4,0.5
])#df.plot.box()

# %%
df2.boxplot()

# %% [markdown]
# 파이차트에서 seaborn 없음

# %%
np.random.seed(1004)
ss=pd.Series(3*np.random.rand(4),index=['a','b','c','d'])
ss
# Out:
# a    0.116855
# b    2.569488
# c    2.239501
# d    2.591784
# dtype: float64

# %%
ss.plot.pie() #시리즈일경우 이렇게 사용가능

# %%
ss.plot.pie(figsize=(6,6))

# %%
ss.plot.pie(labels=['AA','BB','CC','DD'],colors=['r','g','b','c'],
           autopct='%2f',fontsize=15,figsize=(6,6))

# %%
ss.plot.pie(labels=['AA','BB','CC','DD'],colors=['r','g','b','c'],
           autopct='%2f',fontsize=15,figsize=(6,6),
           explode=[0.1,0,0,0.1],
           rotatelabels=25)

# %%
dd=pd.DataFrame({'mass':[0.330,4.87,5.97],
                'radilus':[2439.7,6051.8,6378.1]},
               index=['Mercury','Venus','Earth'])
dd
# Out:
#          mass  radilus
# Mercury  0.33   2439.7
# Venus    4.87   6051.8
# Earth    5.97   6378.1

# %%
dd.plot.pie(y='mass',figsize=(5,5),fontsize=15)

# %% [markdown]
# 두개한꺼번에 그리고싶을떈

# %%
dd.plot.pie(subplots=True,figsize=(6,3))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000227ED556C08>,
# ...
#       dtype=object)

# %%
dd.plot.pie(subplots=True,figsize=(10,5))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000227ED603708>,
# ...
#       dtype=object)

# %% [markdown]
# 산포도:상관관계를 판단하기 위해,두개변수필요

# %%
dd1=sns.load_dataset('tips')
dd1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
dd1.plot.scatter(x='total_bill',y='tip')

# %%
sns.lmplot(x='total_bill',y='tip',data=dd1)

# %%
sns.lmplot(x='total_bill',y='tip',hue='smoker',data=dd1)
#hue는 그룹화하는것과 비슷

# %%
sns.lmplot(x='total_bill',y='tip',hue='sex',data=dd1)

# %%
sns.lmplot(x='total_bill',y='tip',hue='smoker',data=dd1,
          fit_reg=False)

# %% [markdown]
# hexbin
# 데이터 많을 때 어느 부분의 수가 큰지 작은지 구분해서 볼수없는 산점도의
# 단점을 보완

# %%
np.random.seed(1004)
ee=pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])
ee['b']=ee['b']+np.arange(1000)
ee
# Out:
#             a           b
# 0    0.594403    0.402609
# 1   -0.805162    1.115126
# 2   -0.753065    1.215882
# 3    1.461576    4.576076
# 4   -0.171318    3.085518
# ..        ...         ...
# 995 -0.239106  993.833254
# 996  0.339041  995.565155
# 997  0.767092  995.924927
# 998 -0.707685  996.715501
# 999 -0.515246  998.627703
#
# [1000 rows x 2 columns]

# %%
ee.plot.hexbin(x='a',y='b',gridsize=10)

# %%
dd1.plot.hexbin(x='total_bill',y='tip',gridsize=35)

# %%
ee.plot.hexbin(x='a',y='b',gridsize=35)
#gridsize 숫자클수록 자잘해짐
